# %%
import os
import tempfile
import shutil
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import keras_tuner as kt

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.metrics import classification_report, confusion_matrix

# %%
dataset_path = 'dataset'
image_size = (224, 224)
batch_size = 32

if os.path.exists(dataset_path):
    print(f"Dataset bulundu: {dataset_path}")
else:
    print("Dataset bulunamadı")
# Out:
# Dataset bulundu: dataset

# %%
# data loading

datagen = ImageDataGenerator(
    rescale = 1./255, #normalization 
    validation_split = 0.3 # %70 train %30 validation
)

# train dataset settings
train_generator = datagen.flow_from_directory(
    dataset_path,
    target_size = image_size,
    batch_size = batch_size,
    class_mode = 'categorical',
    subset = 'training',
    shuffle = True
)

# validation dataset settings
validation_generator = datagen.flow_from_directory(
    dataset_path,
    target_size = image_size,
    batch_size = batch_size,
    class_mode = 'categorical',
    subset = 'validation',
    shuffle = False
)
# Out:
# Found 36965 images belonging to 38 classes.
# Found 15820 images belonging to 38 classes.

# %%
# hyperparameter tuning - bayesian optimization 
def model_builder(hp):
    base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    base_model.trainable = False

    x = base_model.output
    x = GlobalAveragePooling2D()(x)

    hp_units = hp.Int('units', min_value=32, max_value=512, step=32)
    x = Dense(units=hp_units, activation='relu')(x)
    
    hp_dropout = hp.Float('dropout', min_value=0.0, max_value=0.5, step=0.05)
    x = Dropout(rate=hp_dropout)(x)
    
    hp_learning_rate = hp.Float('learning_rate', min_value=1e-4, max_value=1e-2, sampling='log')

    predictions = Dense(train_generator.num_classes, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=predictions)

    model.compile(optimizer=AdamW(learning_rate=hp_learning_rate),
                  loss='categorical_crossentropy',
                  metrics=['accuracy']) 
    
    return model

temp_dir = tempfile.mkdtemp()

tuner = kt.BayesianOptimization(
    model_builder, 
    objective = 'val_accuracy',
    max_trials = 5,
    overwrite = True,
    directory = temp_dir,        
    project_name = 'plant_disease_tuning'
)

tuner.search(
    train_generator,
    epochs = 5,
    validation_data = validation_generator, 
    verbose = 1
)

best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]


print(f"Best Unit: {best_hps.get('units')}")
print(f"Best Dropout: {best_hps.get('dropout')}")
print(f"Best Learning Rate: {best_hps.get('learning_rate')}")

try:
    shutil.rmtree(temp_dir)
    print("temp klasörü silindi")
except Exception as e:
    print(f"temp klasörü silinirken hata oluştu: {e}")
# Out:
# Trial 5 Complete [00h 24m 24s]
# val_accuracy: 0.9504424929618835
#
# Best val_accuracy So Far: 0.9572060704231262
# Total elapsed time: 02h 17m 09s
# Best Unit: 352
# Best Dropout: 0.30000000000000004
# Best Learning Rate: 0.0004996902435350934
# temp klasörü silindi

# %%
# train model 
model = tuner.hypermodel.build(best_hps)

model.compile(
    optimizer=AdamW(learning_rate=best_hps.get('learning_rate')),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

checkpoint = ModelCheckpoint(
    filepath='plant_disease.h5',
    monitor='val_accuracy',
    mode = 'min',
    save_best_only=True,
    verbose=1
)

history = model.fit(
    train_generator,
    epochs = 20,
    validation_data = validation_generator,
    callbacks=[checkpoint]
)

print("training tamamlandi ve min loss ile model kaydedildi")
# Out:
# Epoch 1/20
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.7466 - loss: 0.9496
# Epoch 1: val_accuracy improved from None to 0.92263, saving model to plant_disease.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 260s 223ms/step - accuracy: 0.8478 - loss: 0.5278 - val_accuracy: 0.9226 - val_loss: 0.2400
# Epoch 2/20
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9295 - loss: 0.2146
# Epoch 2: val_accuracy did not improve from 0.92263
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 272s 235ms/step - accuracy: 0.9307 - loss: 0.2110 - val_accuracy: 0.9480 - val_loss: 0.1616
# Epoch 3/20
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9482 - loss: 0.1594
# Epoch 3: val_accuracy did not improve from 0.92263
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 285s 247ms/step - accuracy: 0.9489 - loss: 0.1539 - val_accuracy: 0.9494 - val_loss: 0.1509
# Epoch 4/20
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9593 - loss: 0.1249
# Epoch 4: val_accuracy did not improve from 0.92263
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 270s 234ms/step - accuracy: 0.9570 - loss: 0.1301 - val_accuracy: 0.9535 - val_loss: 0.1375
# Epoch 5/20
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9660 - loss: 0.1032
# Epoch 5: val_accuracy did not improve from 0.92263
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 269s 233ms/step - accuracy: 0.9647 - loss: 0.1055 - val_accuracy: 0.9568 - val_loss: 0.1267
# Epoch 6/20
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.9699 - loss: 0.0916
# Epoch 6: val_accuracy did not improve from 0.92263
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 286s 247ms/step - accuracy: 0.9691 - loss: 0.0928 - val_accuracy: 0.9570 - val_loss: 0.1331
# Epoch 7/20
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9732 - loss: 0.0744
# Epoch 7: val_accuracy did not improve from 0.92263
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 283s 245ms/step - accuracy: 0.9722 - loss: 0.0775 - val_accuracy: 0.9556 - val_loss: 0.1315
# Epoch 8/20
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.9745 - loss: 0.0731
# Epoch 8: val_accuracy did not improve from 0.92263
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 280s 243ms/step - accuracy: 0.9737 - loss: 0.0735 - val_accuracy: 0.9576 - val_loss: 0.1373
# Epoch 9/20
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.9796 - loss: 0.0588
# Epoch 9: val_accuracy did not improve from 0.92263
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 278s 241ms/step - accuracy: 0.9781 - loss: 0.0629 - val_accuracy: 0.9618 - val_loss: 0.1166
# Epoch 10/20
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9816 - loss: 0.0540
# Epoch 10: val_accuracy did not improve from 0.92263
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 270s 234ms/step - accuracy: 0.9803 - loss: 0.0576 - val_accuracy: 0.9608 - val_loss: 0.1247
# Epoch 11/20
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9840 - loss: 0.0481
# Epoch 11: val_accuracy did not improve from 0.92263
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 267s 231ms/step - accuracy: 0.9825 - loss: 0.0509 - val_accuracy: 0.9564 - val_loss: 0.1422
# Epoch 12/20
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9852 - loss: 0.0431
# Epoch 12: val_accuracy did not improve from 0.92263
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 318s 275ms/step - accuracy: 0.9846 - loss: 0.0449 - val_accuracy: 0.9621 - val_loss: 0.1287
# Epoch 13/20
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9862 - loss: 0.0402
# Epoch 13: val_accuracy did not improve from 0.92263
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 258s 223ms/step - accuracy: 0.9844 - loss: 0.0438 - val_accuracy: 0.9603 - val_loss: 0.1286
# Epoch 14/20
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9878 - loss: 0.0375
# Epoch 14: val_accuracy did not improve from 0.92263
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 262s 226ms/step - accuracy: 0.9869 - loss: 0.0405 - val_accuracy: 0.9624 - val_loss: 0.1256
# Epoch 15/20
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.9893 - loss: 0.0298
# Epoch 15: val_accuracy did not improve from 0.92263
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 269s 232ms/step - accuracy: 0.9872 - loss: 0.0357 - val_accuracy: 0.9655 - val_loss: 0.1219
# Epoch 16/20
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9893 - loss: 0.0313
# Epoch 16: val_accuracy did not improve from 0.92263
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 273s 236ms/step - accuracy: 0.9867 - loss: 0.0364 - val_accuracy: 0.9653 - val_loss: 0.1234
# Epoch 17/20
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9903 - loss: 0.0277
# Epoch 17: val_accuracy did not improve from 0.92263
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 301s 260ms/step - accuracy: 0.9894 - loss: 0.0303 - val_accuracy: 0.9635 - val_loss: 0.1252
# Epoch 18/20
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9895 - loss: 0.0306
# Epoch 18: val_accuracy did not improve from 0.92263
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 255s 220ms/step - accuracy: 0.9886 - loss: 0.0330 - val_accuracy: 0.9631 - val_loss: 0.1373
# Epoch 19/20
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9905 - loss: 0.0272
# Epoch 19: val_accuracy did not improve from 0.92263
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 257s 222ms/step - accuracy: 0.9898 - loss: 0.0287 - val_accuracy: 0.9608 - val_loss: 0.1438
# Epoch 20/20
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.9918 - loss: 0.0240
# Epoch 20: val_accuracy did not improve from 0.92263
# 1156/1156 ━━━━━━━━━━━━━━━━━━━━ 258s 223ms/step - accuracy: 0.9908 - loss: 0.0277 - val_accuracy: 0.9635 - val_loss: 0.1418
# training tamamlandi ve min loss ile model kaydedildi

# %%
# test model 

test_dir = "test_dataset"

# test dataset settings
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

# load best model 
model = tf.keras.models.load_model('plant_disease.h5')

# evaluate model
test_loss, test_accuracy = model.evaluate(test_generator, verbose=1)
print(f'Test Loss: {test_loss}')
print(f'Test Accuracy: {test_accuracy}')

# performance predictions
predictions = model.predict(test_generator, verbose=1)
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes
class_labels = list(test_generator.class_indices.keys())

confusion_matrix = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:")
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=class_labels))
# Out:
# Found 760 images belonging to 38 classes.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 11s 414ms/step - accuracy: 0.8947 - loss: 0.3306
# Test Loss: 0.33059340715408325
# Test Accuracy: 0.8947368264198303
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step
# Confusion Matrix:
# Classification Report:
#                                                     precision    recall  f1-score   support
#
#                                 Apple___Apple_scab       0.90      0.90      0.90        20
#                                  Apple___Black_rot       0.95      0.95      0.95        20
#                           Apple___Cedar_apple_rust       1.00      0.80      0.89        20
#                                    Apple___healthy       0.95      1.00      0.98        20
#                                Blueberry___healthy       0.91      1.00      0.95        20
#           Cherry_(including_sour)___Powdery_mildew       1.00      0.95      0.97        20
#                  Cherry_(including_sour)___healthy       1.00      1.00      1.00        20
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot       0.94      0.80      0.86        20
#                        Corn_(maize)___Common_rust_       1.00      1.00      1.00        20
#                Corn_(maize)___Northern_Leaf_Blight       0.82      0.90      0.86        20
#                             Corn_(maize)___healthy       0.95      0.95      0.95        20
#                                  Grape___Black_rot       0.95      1.00      0.98        20
#                       Grape___Esca_(Black_Measles)       1.00      1.00      1.00        20
#         Grape___Leaf_blight_(Isariopsis_Leaf_Spot)       1.00      1.00      1.00        20
#                                    Grape___healthy       1.00      0.95      0.97        20
#           Orange___Haunglongbing_(Citrus_greening)       1.00      1.00      1.00        20
#                             Peach___Bacterial_spot       1.00      1.00      1.00        20
#                                    Peach___healthy       1.00      1.00      1.00        20
#                      Pepper,_bell___Bacterial_spot       1.00      0.85      0.92        20
#                             Pepper,_bell___healthy       0.87      1.00      0.93        20
#                              Potato___Early_blight       1.00      0.90      0.95        20
#                               Potato___Late_blight       0.83      0.95      0.88        20
#                                   Potato___healthy       1.00      0.50      0.67        20
#                                Raspberry___healthy       0.95      0.90      0.92        20
#                                  Soybean___healthy       0.61      1.00      0.75        20
#                            Squash___Powdery_mildew       1.00      1.00      1.00        20
#                           Strawberry___Leaf_scorch       1.00      1.00      1.00        20
#                               Strawberry___healthy       1.00      1.00      1.00        20
#                            Tomato___Bacterial_spot       0.65      1.00      0.78        20
#                              Tomato___Early_blight       0.62      0.25      0.36        20
#                               Tomato___Late_blight       0.81      0.85      0.83        20
#                                 Tomato___Leaf_Mold       0.69      0.90      0.78        20
#                        Tomato___Septoria_leaf_spot       0.62      0.80      0.70        20
#      Tomato___Spider_mites Two-spotted_spider_mite       0.76      0.95      0.84        20
#                               Tomato___Target_Spot       1.00      0.50      0.67        20
#             Tomato___Tomato_Yellow_Leaf_Curl_Virus       1.00      0.90      0.95        20
#                       Tomato___Tomato_mosaic_virus       1.00      0.55      0.71        20
#                                   Tomato___healthy       0.83      1.00      0.91        20
#
#                                           accuracy                           0.89       760
#                                          macro avg       0.91      0.89      0.89       760
#                                       weighted avg       0.91      0.89      0.89       760
